# %% [markdown]
# # Introduction to Feature Engineering
#
# **Feature Engineering** is the process of selecting, transforming, and enriching data (sample attributes) to improve the performance of machine learning algorithms used to train models.
#
# ![image.png](attachment:80f03405-1fc2-443d-8325-68e56d8936bd.png)
#
# ## Benefits of Feature Engineering
# 1. Improved model accuracy
# 2. Reduced overfitting
# 3. Easier interpretation of results
# 4. More efficient runtime

# %% [markdown]
# ## *Where does Feature Engineering fit?*
#
# >Raw Data → Data Cleaning → **Feature Engineering** → Model Training → Evaluation
#
# ![image.png](attachment:a5ef51b2-49fc-4993-a424-9ab732db0b34.png)

# %% [markdown]
# ---
# # Introduction to Techniques

# %% [markdown]
# ## Imputation
#
# Strategies for **filling missing values**.
# - Statistical substitution (mean, median, mode)
# - Proximity-based methods (KNN, interpolation)
# - Model-based prediction

# %% [markdown]
# ## Selection
#
# **Choosing the most relevant features** to reduce noise and improve generalization.
#
# - Domain knowledge
# - Filter methods (correlation, variance thresholds)
# - Wrapper methods (recursive elimination, forward/backward selection)
# - Embedded methods (L1 regularization, tree-based importance)

# %% [markdown]
# ## Transformation
#
# **Adjusting feature** scales and distributions to improve model performance and convergence.
#
# - Scaling (normalization, standardization)
# - Distribution transforms (log, Box-Cox)
# - Discretization (binning continuous values)

# %% [markdown]
# ## Creation

# %% [markdown]
# **Generating new features** from existing data to capture additional predictive signals.
#
# - Encoding (one-hot, label, target encoding for categoricals)
# - Text vectorization (bag-of-words, TF-IDF, embeddings)
# - Derived features (polynomials, interactions, ratios)
# - Temporal extraction (seasonality, time-since-event)

# %% [markdown]
# ## Extraction

# %% [markdown]
# **Combining features** into lower-dimensional representations while preserving information.
#
# - Linear projections (PCA, LDA, ICA)
# - Non-linear methods (autoencoders, manifold learning)
# - Feature learning (deep networks learn representations automatically)

# %% [markdown]
# ## The End
