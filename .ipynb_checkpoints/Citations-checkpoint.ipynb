# %% [markdown]
# # Citations

# %% [markdown]
# Python Data Science Handbook (Jake VanderPlas) -
# https://jakevdp.github.io/PythonDataScienceHandbook/
#
# Feature Engineering (AWS) -
# https://docs.aws.amazon.com/wellarchitected/latest/machine-learning-lens/feature-engineering.html
#
# Understanding Feature Scaling in Machine Learning (Punyakeerthi BL) -
# https://medium.com/@punya8147_26846/understanding-feature-scaling-in-machine-learning-fe2ea8933b66
#
# Your Guide to Feature Engineering (Diego Lopez Yse) -
# https://lopezyse.medium.com/your-guide-to-feature-engineering-383f7e8b7584
