# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ## Problem 1: Feature Engineering with the Titanic Dataset (60 pts)
# In this assignment, you will practice core feature engineering techniques using the Titanic dataset from seaborn. Your goal is to prepare the data for predicting passenger survival and build a simple regression model.

# %% [markdown]
# Note: before you begin import the following packages and classes

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# You will also need to import the Titanic dataset

# %%
# load the dataset
df = sns.load_dataset('titanic')

# %% [markdown]
# ### Part 1: Imputation (15 pts)

# %% [markdown]
# The age and deck columns contain missing values.
#
# Tasks:
#
# (5 pts) Print the number of missing values for each column in the dataset.
#
# (5 pts) Impute missing values in the age column using the median age.
#
# (5 pts) Impute missing values in the deck column using the mode (most frequent value). Confirm by reprinting number of missing values.
#
# **Hint:** Use df['column'].fillna() for imputation.

# %% [markdown]
# ### Part 2: Feature Selection (10 pts)

# %% [markdown]
# Not all columns are useful for modeling. We want to select relevant numerical and categorical features.
#
# Tasks:
#
# (10 pts) Drop one feature from the pair with the greatest pairwise correlation.
#
# **Hint:** Use df.select_dtypes(include=np.number) to get numerical columns.

# %% [markdown]
# ### Part 3: Feature Creation (20 pts)

# %% [markdown]
# Create new features that may improve model performance.
# Tasks:
#
# (5 pts) Create a new column family_size that combines sibsp (siblings/spouses) and parch (parents/children): family_size = sibsp + parch + 1
#
# (5 pts) Create a new binary column is_alone that equals 1 if alone is True, else 0.
#
# (5 pts) Bin the age column into categories and store in a new column age_group:
#
# 'child': age < 18
# 'adult': 18 <= age < 60
# 'senior': age >= 60
#
# **Hint:** Use pd.cut() with bins=[0, 18, 60, 100] and labels=['child', 'adult', 'senior']
#
# (5 pts) One-hot to encode the pclass, sex and age_group columns into binary using pd.get_dummies().

# %% [markdown]
# ### Part 4: Normalization (15 pts)

# %% [markdown]
# Normalize the numerical columns to prepare the data for modeling.
#
# Tasks:
#
# (5 pts) Select only the numerical columns from the dataframe and store in a new variable df_num.
#
# **Hint:** Use df.select_dtypes(include=np.number)
#
# (5 pts) Apply min-max normalization to df_num using the formula from notes. Store the result in df_normalized.
#
# (5 pts) Print the first 5 rows of df_normalized to verify the transformation.
